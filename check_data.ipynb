# %%
import pandas as pd

# %%
data = pd.read_csv('./data/ai.csv')
print(data.shape)
data.head()
# Out:
# (20, 4)
#                                                 href  \
# 0  //www.cnn.com/2021/04/02/health/autism-awarene...
# 1  //www.cnn.com/2021/04/01/business/compass-ipo-...
# 2  //www.cnn.com/2021/03/30/tech/ibm-cleveland-cl...
# 3  //www.cnn.com/2021/03/29/perspectives/global-d...
# 4  //www.cnn.com/style/article/old-ireland-color-...
#
#                                                title          date  \
# 0  World Autism Awareness Day 2021: What you need...   Apr 2, 2021
# 1  Compass CEO plans to double down on tech inves...   Apr 2, 2021
# 2  Cleveland Clinic and IBM hope their tech partn...  Mar 30, 2021
# 3  We need to create a global standard to protect...  Mar 29, 2021
# 4  AI photo restoration shines a light on life in...  Mar 29, 2021
#
#                                              content
# 0  In many ways, Kevin "Knox" Johnson III is just...
# 1  Riding the tailwinds of months of red hot hous...
# 2  After a year in which scientists raced to unde...
# ...

# %%
data = pd.read_csv('./data/education.csv')
print(data.shape)
data.head()
# Out:
# (20, 4)
#                                                 href  \
# 0  //www.cnn.com/2021/04/04/politics/democrats-ec...
# 1  //www.cnn.com/2021/04/04/uk/uk-race-report-cul...
# 2  //www.cnn.com/2021/04/03/uk/uk-schools-rape-cu...
# 3  //www.cnn.com/2021/04/03/politics/biden-covid-...
# 4  //www.cnn.com/2021/04/02/business/uber-blind-p...
#
#                                                title         date  \
# 0  Democrats have a chance to invest in economic ...  Apr 4, 2021
# 1  Culture wars give Boris Johnson and his govern...  Apr 4, 2021
# 2  UK's elite schools face a reckoning on rape cu...  Apr 3, 2021
# 3  White House hits troubling pandemic crossroads...  Apr 3, 2021
# 4  Uber ordered to pay $1.1 million after blind w...  Apr 3, 2021
#
#                                              content
# 0  For decades, Democrats and their economic advi...
# 1  "Two basic rules of government: Never look int...
# 2  Nine years after being assaulted by a boy she ...
# ...

# %%
data = pd.read_csv('./data/game.csv')
print(data.shape)
data.head()
# Out:
# (20, 4)
#                                                 href  \
# 0  //www.cnn.com/2021/04/04/us/pandemic-hobbies-g...
# 1  //www.cnn.com/2021/04/04/tennis/elina-svitolin...
# 2  //www.cnn.com/2021/04/03/australia/aboriginal-...
# 3  //www.cnn.com/2021/04/03/sport/baylor-v-housto...
# 4  //www.cnn.com/2021/04/04/politics/georgia-voti...
#
#                                                title         date  \
# 0  The Great Depression led to many of the hobbie...  Apr 4, 2021
# 1  Tennis stars Elina Svitolina and Gael Monfils ...  Apr 4, 2021
# 2  Australia's first international cricket team f...  Apr 4, 2021
# 3  Gonzaga defeats UCLA with buzzer beater and wi...  Apr 4, 2021
# 4  As restrictive voting bills multiply, GOP sign...  Apr 4, 2021
#
#                                              content
# 0  In the 1930s, it was the game of Bridge that k...
# 1  It's official! Elina Svitolina and Gael Monfil...
# 2  Growing up in the small community of Harrow in...
# ...

# %%
data = pd.read_csv('./data/book.csv')
print(data.shape)
data.head()
# Out:
# (20, 4)
#                                                 href  \
# 0  //www.cnn.com/2021/04/04/world/neil-degrasse-t...
# 1  //www.cnn.com/2021/04/03/australia/aboriginal-...
# 2  //www.cnn.com/2021/04/03/opinions/easter-jesus...
# 3  //www.cnn.com/2021/04/03/us/covid-19-vaccine-h...
# 4  //www.cnn.com/2021/04/02/us/salman-rushdie-mid...
#
#                                                title         date  \
# 0  Neil deGrasse Tyson on stars, Santa's location...  Apr 4, 2021
# 1  Australia's first international cricket team f...  Apr 4, 2021
# 2                 Why I'm going to church for Easter  Apr 3, 2021
# 3  Read these tips before getting your Covid-19 v...  Apr 3, 2021
# 4  Salman Rushdie reflects on post-colonial India...  Apr 3, 2021
#
#                                              content
# 0  Neil deGrasse Tyson is a man of many parts, co...
# 1  Growing up in the small community of Harrow in...
# 2  "You go to church?"  That's a question I've be...
# ...
